# %% [markdown]
# #  제2장

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %matplotlib inline
from matplotlib import rcParams
from matplotlib import font_manager, rc
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
import numpy as np

###한글 폰트###
rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_csv('house_price1.csv')

# %%
df['price_pyung'] = df['price']/df['size_pyung']

# %%
df.tail()
# Out:
#      Unnamed: 0   price  built_yr dong_name   apt_name    size  gu_code  \
# 191         191  147000      2014       내곡동     서초더샵포레   59.69    11650
# 192         192  160000      2014       내곡동     서초더샵포레   84.81    11650
# 193         193  192500      2014       신원동  서초포레스타5단지  101.35    11650
# 194         194  192500      2014       신원동  서초포레스타5단지  101.35    11650
# 195         195  185000      2014       신원동  서초포레스타5단지   84.41    11650
#
#         date_tr  size_pyung  price_pyung
# 191  2021-06-24   17.924925  8200.871168
# 192  2021-06-28   25.468468  6282.278033
# 193  2021-06-03   30.435435  6324.864332
# 194  2021-06-03   30.435435  6324.864332
# 195  2021-06-11   25.348348  7298.305888

# %% [markdown]
# ### matplotlib

# %%
df.boxplot(column='price_pyung', by='dong_name', notch=True,  color='red', figsize=(8,5))
plt.xlabel("")
plt.title("")
plt.savefig("boxPlot1.png")
plt.show()

# %% [markdown]
# ### seaborn

# %%
sns.color_palette("rainbow", 8) # rainbow 색상표에서 8개의 색상을 가져옴
# Out:
# [(0.2803921568627451, 0.33815827481581706, 0.9851622334675065),
#  (0.0607843137254902, 0.6364742361471413, 0.9410892525013715),
#  (0.16666666666666663, 0.8660254037844386, 0.8660254037844387),
#  (0.38627450980392153, 0.9840863373026044, 0.767362681448697),
#  (0.6137254901960785, 0.9840863373026044, 0.6412133148335784),
#  (0.8333333333333333, 0.8660254037844387, 0.5000000000000001),
#  (1.0, 0.6364742361471414, 0.33815827481581706),
#  (1.0, 0.33815827481581756, 0.17162567916635985)]

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x='dong_name', y='price_pyung', notch=True, palette="rainbow", data=df)
plt.xlabel('')
plt.ylabel('')
plt.grid()
plt.savefig("boxPlot2.png")
plt.show()

# %%
plt.figure(figsize = (8,5))
sns.boxplot(x='dong_name', y='price_pyung', notch=True, palette="rainbow", data=df)
sns.stripplot(x='dong_name', y='price_pyung', data=df, jitter=True, marker='o', alpha=0.3, color='red')
plt.xlabel('')
plt.ylabel('')
plt.grid()
plt.savefig("boxPlot3.png")
plt.show()

# %%
fig, axes = plt.subplots(1, 2,tight_layout=True)
fig.set_size_inches(9, 3)
sns.boxplot(x='dong_name', y='price_pyung', notch=True, palette="rainbow", data=df, ax = axes[0])

sns.boxplot(x='dong_name', y='price_pyung', notch=True, palette="rainbow", data=df, ax = axes[1])
sns.stripplot(x='dong_name', y='price_pyung', data=df, jitter=True, marker='o', alpha=0.3, color='red', s=4, ax = axes[1])

axes[0].set_xlabel('')
axes[0].set_ylabel('')
axes[0].grid()

axes[1].set_xlabel('')
axes[1].set_ylabel('')
axes[1].grid()
plt.savefig("boxPlot4.png")
plt.show()
