# %% [markdown]
# #  제2장

# %% [markdown]
# # 2. Histogram

# %% [markdown]
# ## 2.1 Overview

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %matplotlib inline
from matplotlib import rcParams
from matplotlib import font_manager, rc
import matplotlib.dates as mdates
import seaborn as sns
import pandas as pd
import numpy as np

###한글 폰트###
rcParams['axes.unicode_minus'] = False
#plt.rcParams['font.family'] = 'Malgun Gothic'

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
#df = pd.read_csv("household_2021a.csv", encoding='CP949')

# %%
df = pd.read_csv('house_price1.csv')

# %%
df['price_pyung'] = df['price']/df['size_pyung']

# %%
df.tail()
# Out:
#      Unnamed: 0   price  built_yr dong_name   apt_name    size  gu_code  \
# 191         191  147000      2014       내곡동     서초더샵포레   59.69    11650
# 192         192  160000      2014       내곡동     서초더샵포레   84.81    11650
# 193         193  192500      2014       신원동  서초포레스타5단지  101.35    11650
# 194         194  192500      2014       신원동  서초포레스타5단지  101.35    11650
# 195         195  185000      2014       신원동  서초포레스타5단지   84.41    11650
#
#         date_tr  size_pyung  price_pyung
# 191  2021-06-24   17.924925  8200.871168
# 192  2021-06-28   25.468468  6282.278033
# 193  2021-06-03   30.435435  6324.864332
# 194  2021-06-03   30.435435  6324.864332
# 195  2021-06-11   25.348348  7298.305888

# %%
plt.hist(df['price_pyung'], bins=50, color='g') #bins 구간갯수
plt.ylabel('만원')
plt.grid()
plt.show()

# %%
fig, axs = plt.subplots(1, 2,tight_layout=True)
fig.set_size_inches(9, 3)
x = df['price_pyung']

# density=True 값을 통하여 Y축에 density를 표기할 수 있습니다.
bins=30
axs[0].hist(x, bins=bins, density=True, color='red', cumulative=True)
axs[1].hist(x, bins=bins, density=True, color='cyan')
axs[0].set_xlabel('만원')
axs[1].set_xlabel('만원')
axs[0].grid()
axs[1].grid()
plt.show()

# %%
df1 = df.loc[df['dong_name'].isin(["서초동"])]
df2 = df.loc[df['dong_name'].isin(["반포동"])]

plt.hist(df1['price_pyung'], bins=50, color='g', alpha=0.5, label='서초동') 
plt.hist(df2['price_pyung'], bins=50, color='b', alpha=0.5, label='반포동') 
plt.xlabel('만원')
plt.legend()
plt.grid()
plt.show()

# %%
fig, axes = plt.subplots(1, 2,tight_layout=True)
fig.set_size_inches(9, 3)

x0 = df1['price_pyung']
x1 = df2['price_pyung']

bins=30
sns.histplot(x0, bins=bins, color='g',alpha=0.50, label='서초동', ax = axes[0])
sns.histplot(x1, bins=bins, color='b',alpha=0.50, label='반포동', ax = axes[1])
axes[0].grid()
axes[1].grid()
axes[0].legend()
axes[1].legend()
plt.show()

# %%
fig, axes = plt.subplots(1, 2,tight_layout=True)
fig.set_size_inches(9, 3)

x0 = df1['price_pyung']
x1 = df2['price_pyung']

bins=30
sns.kdeplot(x0, color='g',label='서초동', ax = axes[0])
sns.kdeplot(x1, color='b', label='반포동', ax = axes[1])
axes[0].grid()
axes[1].grid()
axes[0].legend()
axes[1].legend()
plt.savefig("house_price5.png")
plt.show()

# %%
sns.color_palette("hls", 8) # hls 색상표에서 8개의 색상을 가져옴
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.7612000000000001, 0.33999999999999997),
#  (0.5688000000000001, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5012000000000001),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.43879999999999986, 0.86),
#  (0.6311999999999998, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6987999999999996)]

# %%
sns.kdeplot(data = df, x ='price_pyung', hue='dong_name', fill=True, common_norm=False, palette="hls",
   alpha=.8)
plt.grid()
plt.show()
